# %%
import pandas as pd
import numpy as np
import datetime

# %%
dt = pd.read_excel(r"C:\Users\micha.vardy\Desktop\josef_test.xlsx",ignore_index = True, sheet_name = None)

# %%
tabs = ['מיכה ורדי','אורי מנקס','דורון שרף','אביחי בארי','גיא רשקס','סיכום','ממדי טמפרטורה חיצונית']

# %%
for tab in tabs:
    dt[tab].columns = dt[tab].iloc[3]
    dt[tab] = dt[tab].iloc[4:,:]

# %%
df = dt[tabs[0]]
df_dt = df.iloc[:,0]
df.drop(df.columns[5],axis=1,inplace=True)
df['dt'] = df_dt

# %%
micha = df.iloc[:,0:4]
uri = df.iloc[:,4:8]
doron = df.iloc[:,8:12]
avichi = df.iloc[:,12:16]

# %%
micha
# Out:
# 3      F1    F2    F3    FT
# 4       0     0  4.05  4.05
# 5       0     0   4.2   4.2
# 6       0     0  3.02  3.02
# 7       0     0  1.75  1.75
# 8       0     0  1.59  1.59
# 9       0     0  1.72  1.72
# 10      0     0  1.73  1.73
# 11      0     0  1.32  1.32
# 12      0     0  1.24  1.24
# 13      0     0   1.5   1.5
# 14      0     0  1.17  1.17
# 15      0     0  3.04  3.04
# 16      0     0   1.1   1.1
# 17      0     0  1.16  1.16
# 18      0     0   1.1   1.1
# 19      0     0  0.89  0.89
# 20      0     0  2.75  2.75
# 21   0.77     0   0.4  1.17
# 22   0.81     0     0  0.81
# 23   0.32   0.6     0  0.92
# 24      0  0.84     0  0.84
# 25      0  0.46  2.37  2.83
# 26      0     0  3.69  3.69
# 27      0     0  3.99  3.99
# 28      0     0   1.6   1.6
# 29      0     0  1.05  1.05
# 30      0     0  0.53  0.53
# 31      0     0  0.55  0.55
# 32      0     0  0.53  0.53
# 33      0     0  0.52  0.52
# ..    ...   ...   ...   ...
# 697  3.34     0     0  3.34
# ...
